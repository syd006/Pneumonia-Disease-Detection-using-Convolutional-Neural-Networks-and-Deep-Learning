# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
from tensorflow.keras.optimizers import RMSprop
from sklearn.model_selection import GridSearchCV


from sklearn.model_selection import StratifiedKFold

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150

# %%
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# Loading the Dataset
train = get_data('/content/drive/MyDrive/CNN pneumonia/chest_xray/train')
test = get_data('/content/drive/MyDrive/CNN pneumonia/chest_xray/test')
val = get_data('/content/drive/MyDrive/CNN pneumonia/chest_xray/val')
# Out:
# <ipython-input-25-c67035924b0b>:13: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
train[1]
# Out:
# array([array([[ 4,  3,  8, ...,  6,  6,  7],
#               [ 4,  3,  8, ...,  6,  6,  7],
#               [ 3,  3,  5, ...,  6,  6,  6],
#               ...,
#               [ 2, 17, 18, ..., 13, 13, 13],
#               [ 6, 17, 20, ..., 14, 14, 14],
#               [ 7, 17, 20, ..., 14, 14, 14]], dtype=uint8), 0],
#       dtype=object)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")
print(l)
print(l.count('Pneumonia'))
l.count('Normal')
# Out:
# ['Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumon ...
# 3875
# 1341

# %%
df = pd.DataFrame({'Class': l})
sns.set_style('darkgrid')
sns.countplot(data=df, x='Class')
plt.show()

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = np.array([i[0] for i in train]) / 255.0
y_train = np.array([i[1] for i in train])

x_val = np.array([i[0] for i in val]) / 255.0
y_val = np.array([i[1] for i in val])

x_test = np.array([i[0] for i in test]) / 255.0
y_test = np.array([i[1] for i in test])

x_train = x_train.reshape(-1, img_size, img_size, 1)
x_val = x_val.reshape(-1, img_size, img_size, 1)
x_test = x_test.reshape(-1, img_size, img_size, 1)

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
)

datagen.fit(x_train)

# %%
model = Sequential()
# Add Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, and Dense layers

model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

model.compile(optimizer="rmsprop", loss='binary_crossentropy', metrics=['accuracy'])
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)
history = model.fit(datagen.flow(x_train, y_train, batch_size=16),
                    epochs=15,
                    validation_data=datagen.flow(x_val, y_val),
                    callbacks=[learning_rate_reduction])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 150, 150, 32)      320
#
#  batch_normalization_15 (Ba  (None, 150, 150, 32)      128
#  tchNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 75, 75, 32)        0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (None, 75, 75, 64)        18496
#
#  dropout_12 (Dropout)        (None, 75, 75, 64)        0
#
#  batch_normalization_16 (Ba  (None, 75, 75, 64)        256
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 38, 38, 64)        0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 38, 38, 64)        36928
#
#  batch_normalization_17 (Ba  (None, 38, 38, 64)        256
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 19, 19, 64)        0
#  ng2D)
#
#  conv2d_18 (Conv2D)          (None, 19, 19, 128)       73856
#
#  dropout_13 (Dropout)        (None, 19, 19, 128)       0
#
#  batch_normalization_18 (Ba  (None, 19, 19, 128)       512
#  tchNormalization)
#
#  max_pooling2d_18 (MaxPooli  (None, 10, 10, 128)       0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 10, 10, 256)       295168
#
#  dropout_14 (Dropout)        (None, 10, 10, 256)       0
#
#  batch_normalization_19 (Ba  (None, 10, 10, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_19 (MaxPooli  (None, 5, 5, 256)         0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 6400)              0
#
#  dense_6 (Dense)             (None, 128)               819328
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1246401 (4.75 MB)
# Trainable params: 1245313 (4.75 MB)
# Non-trainable params: 1088 (4.25 KB)
# _________________________________________________________________
# Epoch 1/15
# 326/326 [==============================] - 398s 1s/step - loss: 0.4748 - accuracy: 0.8445 - val_loss: 24.9554 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/15
# 326/326 [==============================] - 375s 1s/step - loss: 0.2723 - accuracy: 0.9013 - val_loss: 31.9757 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 3/15
# 326/326 [==============================] - 372s 1s/step - loss: 0.2460 - accuracy: 0.9172 - val_loss: 0.5852 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 4/15
# 326/326 [==============================] - 370s 1s/step - loss: 0.2017 - accuracy: 0.9317 - val_loss: 1.0598 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/15
# 326/326 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9310
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 326/326 [==============================] - 369s 1s/step - loss: 0.2043 - accuracy: 0.9310 - val_loss: 117.9206 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 6/15
# 326/326 [==============================] - 376s 1s/step - loss: 0.1350 - accuracy: 0.9555 - val_loss: 77.4947 - val_accuracy: 0.5000 - lr: 3.0000e-04
# Epoch 7/15
# 326/326 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9586
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 326/326 [==============================] - 378s 1s/step - loss: 0.1304 - accuracy: 0.9586 - val_loss: 0.6872 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 8/15
# 326/326 [==============================] - 370s 1s/step - loss: 0.1079 - accuracy: 0.9645 - val_loss: 0.4004 - val_accuracy: 0.8750 - lr: 9.0000e-05
# Epoch 9/15
# 326/326 [==============================] - 367s 1s/step - loss: 0.1213 - accuracy: 0.9615 - val_loss: 0.4782 - val_accuracy: 0.6250 - lr: 9.0000e-05
# Epoch 10/15
# 326/326 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9657
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 326/326 [==============================] - 365s 1s/step - loss: 0.1046 - accuracy: 0.9657 - val_loss: 1.0006 - val_accuracy: 0.5625 - lr: 9.0000e-05
# Epoch 11/15
# 326/326 [==============================] - 368s 1s/step - loss: 0.1042 - accuracy: 0.9670 - val_loss: 0.9843 - val_accuracy: 0.6875 - lr: 2.7000e-05
# Epoch 12/15
# 326/326 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9645
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 326/326 [==============================] - 372s 1s/step - loss: 0.1137 - accuracy: 0.9645 - val_loss: 0.7079 - val_accuracy: 0.6875 - lr: 2.7000e-05
# Epoch 13/15
# 326/326 [==============================] - 370s 1s/step - loss: 0.0959 - accuracy: 0.9672 - val_loss: 0.4626 - val_accuracy: 0.5625 - lr: 8.1000e-06
# Epoch 14/15
# 326/326 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9693
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 326/326 [==============================] - 370s 1s/step - loss: 0.0958 - accuracy: 0.9693 - val_loss: 0.5548 - val_accuracy: 0.6250 - lr: 8.1000e-06
# Epoch 15/15
# 326/326 [==============================] - 370s 1s/step - loss: 0.0950 - accuracy: 0.9672 - val_loss: 0.4465 - val_accuracy: 0.6250 - lr: 2.4300e-06

# %%
print("Loss of the model is - ", model.evaluate(x_test, y_test)[0])
print("Accuracy of the model is - ", model.evaluate(x_test, y_test)[1] * 100, "%")
# Out:
# 20/20 [==============================] - 13s 635ms/step - loss: 0.2604 - accuracy: 0.9247
# Loss of the model is -  0.26036444306373596
# 20/20 [==============================] - 12s 571ms/step - loss: 0.2604 - accuracy: 0.9247
# Accuracy of the model is -  92.46794581413269 %

# %%
# Plotting Training & Validation Accuracy and Loss
epochs = [i for i in range(15)]
fig, ax = plt.subplots(1, 2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(12, 5)

ax[0].plot(epochs, train_acc, 'go-', label='Training Accuracy')
ax[0].plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs, train_loss, 'g-o', label='Training Loss')
ax[1].plot(epochs, val_loss, 'r-o', label='Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
# Assuming your predictions are probabilities
predictions_proba = model.predict(x_test)

# Round probabilities to obtain class labels
predictions = np.round(predictions_proba).astype(int)

# Display Classification Report
print(classification_report(y_test, predictions, target_names=['Pneumonia (Class 0)', 'Normal (Class 1)']))
# Out:
# 20/20 [==============================] - 17s 850ms/step
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.92      0.96      0.94       390
#    Normal (Class 1)       0.93      0.87      0.90       234
#
#            accuracy                           0.92       624
#           macro avg       0.93      0.91      0.92       624
#        weighted avg       0.92      0.92      0.92       624

# %%
# Display Confusion Matrix
cm = confusion_matrix(y_test, predictions)
cm = pd.DataFrame(cm, index=['0', '1'], columns=['0', '1'])
plt.figure(figsize=(10, 10))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=labels, yticklabels=labels)
plt.show()

# %%
correct = np.nonzero(predictions == y_test)[0]
incorrect = np.nonzero(predictions != y_test)[0]

# %%
i = 0
for c in correct[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1
# Out:
# <ipython-input-42-3b0e8ec19e68>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)

# %%
i = 0
for c in incorrect[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},Actual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1
# Out:
# <ipython-input-43-d863d2b73908>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,i+1)
